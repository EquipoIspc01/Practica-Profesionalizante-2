# %% [markdown]
# Enlace al dataset: https://drive.google.com/file/d/1GezJacAQFlnm2tWMUMiplKtj3hm5xV4h/view?usp=sharing

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_json('MLA_100k (2).jsonlines', lines=True)

# %%
df.condition.value_counts(dropna=False)
# Out:
# new     53758
# used    46242
# Name: condition, dtype: int64

# %%
df['target'] = np.where(df['condition']=='new', 1, 0)

# %%
#pip install autoviz==0.1.55

# %%
#pip install pycaret

# %%
# init setup
from pycaret.classification import *
exp_name = setup(data =df,  target = 'target', fold_shuffle=True) --y
# Out:
# IntProgress(value=0, description='Processing: ', max=3)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .            01:00:15
# Status     . . . . . . . . . . . . . . . . . .  Preprocessing Data
# Text(value="Following data types have been inferred automatically, if they are correct press enter to continue…
#                                     Data Type
# seller_address                    Categorical
# warranty                          Categorical
# sub_status                        Categorical
# condition                         Categorical
# seller_contact                    Categorical
# deal_ids                          Categorical
# base_price                            Numeric
# shipping                          Categorical
# non_mercado_pago_payment_methods  Categorical
# seller_id                             Numeric
# variations                        Categorical
# location                          Categorical
# site_id                           Categorical
# ...
